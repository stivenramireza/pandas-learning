# %% [markdown]
# ## Pandas Intermediate for Data Science

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/VinitaSilaparasetty/Coursera-Intermediate-Pandas/master/What_does_aid_to_Africa_finance_1.csv")
df.head(3)
# Out:
#        countryc  year       agrgdp       popn      infmort schprim schsec  \
# 0  Burkina Faso  1970  35.44188862  5633000.0  141.3999939      13      1
# 1  Burkina Faso  1970  35.44188862  5633000.0  141.3999939      13      1
# 2  Burkina Faso  1971  36.16739069  5740700.0  139.1999969    13.6    1.2
#
#             grtdsbp           grlndsbp           aiddsbp  ...  \
# 0  13.3182802200317   1.02303504943848  14.3413200378418  ...
# 1  13.3182802200317   1.02303504943848  14.3413200378418  ...
# 2  16.7043991088867  0.655763506889343  17.3601703643799  ...
#
#                 dcurexpp               dcapexpp               dprirepp  \
# 0  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
# 1  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
# 2  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
#
#                 dcnlnagp               dcnlnenp               dcnlninp  \
# ...

# %% [markdown]
# ### Splitting data

# %%
df_new = df.copy()

# %%
df_1 = df_new.sample(frac=0.25, random_state=0)
df_new = df_new.drop(df_1.index)

# %%
df_2 = df_new.sample(frac=0.25, random_state=0)
df_new = df_new.drop(df_2.index)

# %%
df_3 = df_new.sample(frac=0.25, random_state=0)
df_4 = df_new.drop(df_3.index)

# %% [markdown]
# ### Detect missing values

# %%
df_3.isnull().sum()
# Out:
# countryc     0
# year         0
# agrgdp       0
# popn         1
# infmort      0
# schprim      0
# schsec       0
# grtdsbp      0
# grlndsbp     0
# aiddsbp      0
# totexpp      0
# agexpp       0
# enexpp       0
# indexpp      0
# tacexpp      0
# eduexpp      0
# hthexpp      0
# prirepp      0
# curexpp      0
# capexpp      0
# gdnpp        0
# d0           0
# cnlnagp      0
# cnlnenp      0
# cnlninp      0
# cnlntacp     0
# cnlnedup     0
# cnlnhthp     0
# cnlnothp     0
# dgrtdsbp     0
# dgrlndsbp    0
# daiddsbp     0
# dtotexpp     0
# dagexpp      0
# denexpp      0
# dindexpp     0
# dtacexpp     0
# deduexpp     0
# dhthexpp     0
# dothexpp     0
# dcurexpp     0
# dcapexpp     0
# dprirepp     0
# dcnlnagp     0
# dcnlnenp     0
# dcnlninp     0
# dcnlntacp    0
# dcnlnedup    0
# dcnlnhthp    0
# dcnlnothp    0
# dtype: int64

# %% [markdown]
# #### - Imputation

# %%
df_3['popn'].mean()
# Out:
# 12570541.658536585

# %%
df_3.isnull()
# Out:
#      countryc   year  agrgdp   popn  infmort  schprim  schsec  grtdsbp  \
# 237     False  False   False  False    False    False   False    False
# 244     False  False   False  False    False    False   False    False
# 299     False  False   False  False    False    False   False    False
# 87      False  False   False  False    False    False   False    False
# 91      False  False   False  False    False    False   False    False
# 260     False  False   False  False    False    False   False    False
# 14      False  False   False  False    False    False   False    False
# 157     False  False   False  False    False    False   False    False
# 207     False  False   False  False    False    False   False    False
# 160     False  False   False  False    False    False   False    False
# 255     False  False   False  False    False    False   False    False
# 9       False  False   False  False    False    False   False    False
# ...

# %%
df_3['popn'].fillna(df_3['popn'].mean, inplace=True)

# %%
df_3.isnull().sum()
# Out:
# countryc     0
# year         0
# agrgdp       0
# popn         0
# infmort      0
# schprim      0
# schsec       0
# grtdsbp      0
# grlndsbp     0
# aiddsbp      0
# totexpp      0
# agexpp       0
# enexpp       0
# indexpp      0
# tacexpp      0
# eduexpp      0
# hthexpp      0
# prirepp      0
# curexpp      0
# capexpp      0
# gdnpp        0
# d0           0
# cnlnagp      0
# cnlnenp      0
# cnlninp      0
# cnlntacp     0
# cnlnedup     0
# cnlnhthp     0
# cnlnothp     0
# dgrtdsbp     0
# dgrlndsbp    0
# daiddsbp     0
# dtotexpp     0
# dagexpp      0
# denexpp      0
# dindexpp     0
# dtacexpp     0
# deduexpp     0
# dhthexpp     0
# dothexpp     0
# dcurexpp     0
# dcapexpp     0
# dprirepp     0
# dcnlnagp     0
# dcnlnenp     0
# dcnlninp     0
# dcnlntacp    0
# dcnlnedup    0
# dcnlnhthp    0
# dcnlnothp    0
# dtype: int64

# %% [markdown]
# #### - Interpolation

# %%
df_1.isnull().sum()
# Out:
# countryc     0
# year         0
# agrgdp       0
# popn         1
# infmort      0
# schprim      0
# schsec       0
# grtdsbp      0
# grlndsbp     0
# aiddsbp      0
# totexpp      0
# agexpp       0
# enexpp       0
# indexpp      0
# tacexpp      0
# eduexpp      0
# hthexpp      0
# prirepp      0
# curexpp      0
# capexpp      0
# gdnpp        0
# d0           0
# cnlnagp      0
# cnlnenp      0
# cnlninp      0
# cnlntacp     0
# cnlnedup     0
# cnlnhthp     0
# cnlnothp     0
# dgrtdsbp     0
# dgrlndsbp    0
# daiddsbp     0
# dtotexpp     0
# dagexpp      0
# denexpp      0
# dindexpp     0
# dtacexpp     0
# deduexpp     0
# dhthexpp     0
# dothexpp     0
# dcurexpp     0
# dcapexpp     0
# dprirepp     0
# dcnlnagp     0
# dcnlnenp     0
# dcnlninp     0
# dcnlntacp    0
# dcnlnedup    0
# dcnlnhthp    0
# dcnlnothp    0
# dtype: int64

# %%
df_1['popn'].fillna(df_1['popn'].inteporlate(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-62e1e87a6e1b> in <module>
# ----> 1 df_1['popn'].fillna(df_1['popn'].inteporlate(), inplace=True)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'inteporlate'

# %%
df_1.isnull().sum()
# Out:
# countryc     0
# year         0
# agrgdp       0
# popn         1
# infmort      0
# schprim      0
# schsec       0
# grtdsbp      0
# grlndsbp     0
# aiddsbp      0
# totexpp      0
# agexpp       0
# enexpp       0
# indexpp      0
# tacexpp      0
# eduexpp      0
# hthexpp      0
# prirepp      0
# curexpp      0
# capexpp      0
# gdnpp        0
# d0           0
# cnlnagp      0
# cnlnenp      0
# cnlninp      0
# cnlntacp     0
# cnlnedup     0
# cnlnhthp     0
# cnlnothp     0
# dgrtdsbp     0
# dgrlndsbp    0
# daiddsbp     0
# dtotexpp     0
# dagexpp      0
# denexpp      0
# dindexpp     0
# dtacexpp     0
# deduexpp     0
# dhthexpp     0
# dothexpp     0
# dcurexpp     0
# dcapexpp     0
# dprirepp     0
# dcnlnagp     0
# dcnlnenp     0
# dcnlninp     0
# dcnlntacp    0
# dcnlnedup    0
# dcnlnhthp    0
# dcnlnothp    0
# dtype: int64

# %% [markdown]
# #### Challenge
#
# Detect missing values in df2 and decide on the best method to handle them with respect to infant mortality rate.

# %%
df_2.isnull().sum()
# Out:
# countryc     0
# year         0
# agrgdp       0
# popn         1
# infmort      0
# schprim      0
# schsec       0
# grtdsbp      0
# grlndsbp     0
# aiddsbp      0
# totexpp      0
# agexpp       0
# enexpp       0
# indexpp      0
# tacexpp      0
# eduexpp      0
# hthexpp      0
# prirepp      0
# curexpp      0
# capexpp      0
# gdnpp        0
# d0           0
# cnlnagp      0
# cnlnenp      0
# cnlninp      0
# cnlntacp     0
# cnlnedup     0
# cnlnhthp     0
# cnlnothp     0
# dgrtdsbp     0
# dgrlndsbp    0
# daiddsbp     0
# dtotexpp     0
# dagexpp      0
# denexpp      0
# dindexpp     0
# dtacexpp     0
# deduexpp     0
# dhthexpp     0
# dothexpp     0
# dcurexpp     0
# dcapexpp     0
# dprirepp     0
# dcnlnagp     0
# dcnlnenp     0
# dcnlninp     0
# dcnlntacp    0
# dcnlnedup    0
# dcnlnhthp    0
# dcnlnothp    0
# dtype: int64

# %%
df_2['popn'].fillna(df_2['popn'].interpolate(), inplace=True)

# %%
df_2.isnull().sum()
# Out:
# countryc     0
# year         0
# agrgdp       0
# popn         0
# infmort      0
# schprim      0
# schsec       0
# grtdsbp      0
# grlndsbp     0
# aiddsbp      0
# totexpp      0
# agexpp       0
# enexpp       0
# indexpp      0
# tacexpp      0
# eduexpp      0
# hthexpp      0
# prirepp      0
# curexpp      0
# capexpp      0
# gdnpp        0
# d0           0
# cnlnagp      0
# cnlnenp      0
# cnlninp      0
# cnlntacp     0
# cnlnedup     0
# cnlnhthp     0
# cnlnothp     0
# dgrtdsbp     0
# dgrlndsbp    0
# daiddsbp     0
# dtotexpp     0
# dagexpp      0
# denexpp      0
# dindexpp     0
# dtacexpp     0
# deduexpp     0
# dhthexpp     0
# dothexpp     0
# dcurexpp     0
# dcapexpp     0
# dprirepp     0
# dcnlnagp     0
# dcnlnenp     0
# dcnlninp     0
# dcnlntacp    0
# dcnlnedup    0
# dcnlnhthp    0
# dcnlnothp    0
# dtype: int64

# %% [markdown]
# ### Joining

# %%
df_5 = df_1.join(df_2, lsuffix='_left')

# %%
df_5
# Out:
#     countryc_left  year_left  agrgdp_left   popn_left infmort_left  \
# 223       Lesotho       1983  23.91304348   1483270.0           98
# 150   Gambia, The       1988  31.22936246    841250.0  140.7799988
# 226       Lesotho       1986  21.14252061   1603960.0           92
# 296        Malawi       1976  39.20110669   5409980.0        179.8
# 52       Botswana       1994  5.199306759   1420270.0  55.39999898
# ..            ...        ...          ...         ...          ...
# 20   Burkina Faso       1988  48.94457166   8534390.0        107.8
# 46       Botswana       1988  7.060807251   1195140.0         56.6
# 158         Kenya       1970  33.29286623  11498000.0          102
# 230       Lesotho       1990  19.96355858   1783000.0         84.6
# 179         Kenya       1991  28.14106137  24015140.0         61.4
#
#     schprim_left schsec_left      grtdsbp_left     grlndsbp_left  \
# 223        106.8          21  87.4762725830078  20.0394096374512
# ...

# %% [markdown]
# ### Concatenation

# %%
df_6 = pd.concat([df_1, df_2], axis=0)
df_6
# Out:
#          countryc  year       agrgdp        popn      infmort      schprim  \
# 223       Lesotho  1983  23.91304348   1483270.0           98        106.8
# 150   Gambia, The  1988  31.22936246    841250.0  140.7799988           65
# 226       Lesotho  1986  21.14252061   1603960.0           92          109
# 296        Malawi  1976  39.20110669   5409980.0        179.8           56
# 52       Botswana  1994  5.199306759   1420270.0  55.39999898          117
# ..            ...   ...          ...         ...          ...          ...
# 240    Madagascar  1974  34.22234966   7408570.0        163.2           94
# 256    Madagascar  1990  32.30721538  11672000.0  101.1600006           87
# 98       Ethiopia  1988  49.15748278  47643232.0        129.4        34.25
# 23   Burkina Faso  1991  34.66403162   9269910.0        104.2           37
# 191       Liberia  1977  31.87008374   1708160.0          167  60.66666667
#
# ...

# %% [markdown]
# ### Advanced Joins

# %% [markdown]
# #### Inner Join

# %%
df_7 = pd.merge(df_1, df_2, on='countryc')
df_7
# Out:
#     countryc  year_x     agrgdp_x     popn_x    infmort_x schprim_x schsec_x  \
# 0    Lesotho    1983  23.91304348  1483270.0           98     106.8       21
# 1    Lesotho    1983  23.91304348  1483270.0           98     106.8       21
# 2    Lesotho    1983  23.91304348  1483270.0           98     106.8       21
# 3    Lesotho    1983  23.91304348  1483270.0           98     106.8       21
# 4    Lesotho    1983  23.91304348  1483270.0           98     106.8       21
# ..       ...     ...          ...        ...          ...       ...      ...
# 356    Ghana    1970  46.51883327  8614000.0  110.5999985        64       14
# 357    Ghana    1970  46.51883327  8614000.0  110.5999985        64       14
# 358    Ghana    1970  46.51883327  8614000.0  110.5999985        64       14
# 359    Ghana    1970  46.51883327  8614000.0  110.5999985        64       14
# 360    Ghana    1970  46.51883327  8614000.0  110.5999985        64       14
#
# ...

# %% [markdown]
# #### Full Outer Inclusive Join

# %%
df_8 = pd.merge(df_1, df_2, how='outer')
df_8
# Out:
#          countryc  year       agrgdp        popn      infmort      schprim  \
# 0         Lesotho  1983  23.91304348   1483270.0           98        106.8
# 1     Gambia, The  1988  31.22936246    841250.0  140.7799988           65
# 2         Lesotho  1986  21.14252061   1603960.0           92          109
# 3          Malawi  1976  39.20110669   5409980.0        179.8           56
# 4        Botswana  1994  5.199306759   1420270.0  55.39999898          117
# ..            ...   ...          ...         ...          ...          ...
# 126    Madagascar  1974  34.22234966   7408570.0        163.2           94
# 127    Madagascar  1990  32.30721538  11672000.0  101.1600006           87
# 128      Ethiopia  1988  49.15748278  47643232.0        129.4        34.25
# 129  Burkina Faso  1991  34.66403162   9269910.0        104.2           37
# 130       Liberia  1977  31.87008374   1708160.0          167  60.66666667
#
# ...

# %% [markdown]
# #### Left Inclusive Join

# %%
df_9 = pd.merge(df_1, df_2, how='left')
df_9
# Out:
#         countryc  year       agrgdp        popn      infmort schprim schsec  \
# 0        Lesotho  1983  23.91304348   1483270.0           98   106.8     21
# 1    Gambia, The  1988  31.22936246    841250.0  140.7799988      65  15.25
# 2        Lesotho  1986  21.14252061   1603960.0           92     109   23.4
# 3         Malawi  1976  39.20110669   5409980.0        179.8      56      4
# 4       Botswana  1994  5.199306759   1420270.0  55.39999898     117     53
# ..           ...   ...          ...         ...          ...     ...    ...
# 70  Burkina Faso  1988  48.94457166   8534390.0        107.8    33.5    6.5
# 71      Botswana  1988  7.060807251   1195140.0         56.6  111.75  35.75
# 72         Kenya  1970  33.29286623  11498000.0          102      58      9
# 73       Lesotho  1990  19.96355858   1783000.0         84.6     105     25
# 74         Kenya  1991  28.14106137  24015140.0         61.4      93     28
#
# ...

# %% [markdown]
# #### Right Inclusive Join

# %%
df_10 = pd.merge(df_1, df_2, how='right')
df_10
# Out:
#         countryc  year                 agrgdp        popn      infmort  \
# 0          Kenya  1980            32.59223808  16560000.0  72.40000153
# 1          Ghana  1973            48.97463727   9388140.0          106
# 2        Liberia  1990  1.79769313486232e+308   2435000.0        176.8
# 3     Madagascar  1981            33.07584521   8951460.0          134
# 4       Ethiopia  1989            48.50468489  49337260.0        126.8
# 5        Lesotho  1988            24.40058125   1689570.0         88.2
# 6          Kenya  1984            33.91489131  19302140.0         64.8
# 7       Ethiopia  1987            49.64547916  46087060.0          132
# 8      Mauritius  1984              14.406639   1011330.0         26.4
# 9        Lesotho  1980            23.58414239   1367000.0  108.4000015
# 10       Liberia  1974            32.28125548   1560820.0        175.4
# 11         Ghana  1990            47.85769483  14870000.0  82.74000092
# ...

# %% [markdown]
# ### Challenge
#
# Generate a new data frame which contains information only from those African countries with the same 'Agriculture as a Share of GDP'.

# %%
df_GDP = pd.merge(df_1, df_2, on='agrgdp')

# %%
df_GDP
# Out:
#   countryc_x  year_x                 agrgdp      popn_x    infmort_x  \
# 0   Ethiopia    1979            56.27994714  36696848.0          153
# 1   Ethiopia    1979            56.27994714  36696848.0          153
# 2   Ethiopia    1980            56.27994714  37717000.0          155
# 3   Ethiopia    1980            56.27994714  37717000.0          155
# 4    Liberia    1991  1.79769313486232e+308   2483450.0        188.4
# 5    Liberia    1991  1.79769313486232e+308   2483450.0        188.4
# 6   Ethiopia    1971  1.79769313486232e+308  29698260.0  156.4000015
# 7   Ethiopia    1971  1.79769313486232e+308  29698260.0  156.4000015
#
#                schprim_x               schsec_x         grtdsbp_x  \
# 0                     37                     10  5.80811786651611
# 1                     37                     10  5.80811786651611
# 2                     34                      8  7.98918008804321
# 3                     34                      8  7.98918008804321
# ...

# %% [markdown]
# ### Sorting

# %% [markdown]
# #### Sort values by a single column

# %%
df_1.sort_values(by=['agrgdp'], ascending=True)
# Out:
#       countryc  year                 agrgdp        popn      infmort  \
# 81    Ethiopia  1971  1.79769313486232e+308  29698260.0  156.4000015
# 205    Liberia  1991  1.79769313486232e+308   2483450.0        188.4
# 285  Mauritius  1992            10.82725922   1081000.0           18
# 282  Mauritius  1989            12.32418189   1048560.0         21.6
# 234    Lesotho  1994            13.69297806   1938930.0  77.39999898
# ..         ...   ...                    ...         ...          ...
# 90    Ethiopia  1980            56.27994714  37717000.0          155
# 118      Ghana  1982            57.34115279  11366410.0           98
# 101   Ethiopia  1991            59.13332578  52954000.0        121.6
# 46    Botswana  1988            7.060807251   1195140.0         56.6
# 286  Mauritius  1993            9.715403179   1097000.0  17.35999997
#
#                    schprim                 schsec           grtdsbp  \
# 81                    17.6                    4.4  2.73099207878113
# ...

# %% [markdown]
# #### Sort values by row labels

# %%
df_1.sort_index(axis=0, ascending=True)
# Out:
#          countryc  year       agrgdp       popn      infmort schprim schsec  \
# 5    Burkina Faso  1973  34.83428571  5958700.0          135    14.8    1.6
# 7    Burkina Faso  1975  34.27100776  6202000.0          131      16      2
# 8    Burkina Faso  1976  34.80431988        NaN          129      15      2
# 12   Burkina Faso  1980  33.24267254  6962000.0          121      18      3
# 15   Burkina Faso  1983   31.9042673  7490710.0        115.4    24.6    4.2
# ..            ...   ...          ...        ...          ...     ...    ...
# 285     Mauritius  1992  10.82725922  1081000.0           18     107     57
# 286     Mauritius  1993  9.715403179  1097000.0  17.35999997     106     59
# 294        Malawi  1974  41.17239788  5087140.0        185.4    51.6      4
# 295        Malawi  1975  37.23468769  5244000.0        182.6    53.8      4
# 296        Malawi  1976  39.20110669  5409980.0        179.8      56      4
#
# ...

# %% [markdown]
# ### Challenge
#
# Sort the values in df3 according to the least 'Secondary School Enrolment Rate'. Select the best method for sorting to solve this challenge.

# %%
# df_3.sort_values(by=['schsec'], ascending=True)

# %% [markdown]
# ### Selection

# %% [markdown]
# #### Select columns by their names

# %%
df_1[['countryc', 'year']]
# Out:
#          countryc  year
# 223       Lesotho  1983
# 150   Gambia, The  1988
# 226       Lesotho  1986
# 296        Malawi  1976
# 52       Botswana  1994
# ..            ...   ...
# 20   Burkina Faso  1988
# 46       Botswana  1988
# 158         Kenya  1970
# 230       Lesotho  1990
# 179         Kenya  1991
#
# [75 rows x 2 columns]

# %% [markdown]
# #### Select columns by index

# %%
df_1[df_1.columns[1:8]].head()
# Out:
#      year       agrgdp       popn      infmort schprim schsec  \
# 223  1983  23.91304348  1483270.0           98   106.8     21
# 150  1988  31.22936246   841250.0  140.7799988      65  15.25
# 226  1986  21.14252061  1603960.0           92     109   23.4
# 296  1976  39.20110669  5409980.0        179.8      56      4
# 52   1994  5.199306759  1420270.0  55.39999898     117     53
#
#               grtdsbp
# 223  87.4762725830078
# 150  113.245697021484
# 226  66.7168197631836
# 296   14.338809967041
# 52   58.7042083740234

# %% [markdown]
# ### Slicing

# %%
df.iloc[:3]
# Out:
#        countryc  year       agrgdp       popn      infmort schprim schsec  \
# 0  Burkina Faso  1970  35.44188862  5633000.0  141.3999939      13      1
# 1  Burkina Faso  1970  35.44188862  5633000.0  141.3999939      13      1
# 2  Burkina Faso  1971  36.16739069  5740700.0  139.1999969    13.6    1.2
#
#             grtdsbp           grlndsbp           aiddsbp  ...  \
# 0  13.3182802200317   1.02303504943848  14.3413200378418  ...
# 1  13.3182802200317   1.02303504943848  14.3413200378418  ...
# 2  16.7043991088867  0.655763506889343  17.3601703643799  ...
#
#                 dcurexpp               dcapexpp               dprirepp  \
# 0  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
# 1  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
# 2  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
#
#                 dcnlnagp               dcnlnenp               dcnlninp  \
# ...

# %%
df.loc[:3]
# Out:
#        countryc  year       agrgdp       popn      infmort schprim schsec  \
# 0  Burkina Faso  1970  35.44188862  5633000.0  141.3999939      13      1
# 1  Burkina Faso  1970  35.44188862  5633000.0  141.3999939      13      1
# 2  Burkina Faso  1971  36.16739069  5740700.0  139.1999969    13.6    1.2
# 3  Burkina Faso  1972  37.51058767  5848380.0          137    14.2    1.4
#
#             grtdsbp           grlndsbp           aiddsbp  ...  \
# 0  13.3182802200317   1.02303504943848  14.3413200378418  ...
# 1  13.3182802200317   1.02303504943848  14.3413200378418  ...
# 2  16.7043991088867  0.655763506889343  17.3601703643799  ...
# 3  20.9176502227783   2.97720909118652  23.8948593139648  ...
#
#                 dcurexpp               dcapexpp               dprirepp  \
# 0  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
# 1  1.79769313486232e+308  1.79769313486232e+308  1.79769313486232e+308
# ...

# %% [markdown]
# ### Challenge
#
# Select only those values in df4 that relate to the concessionary loans to various sectors in Africa.

# %%
df_4[df_4.columns[22:29]].head()
# Out:
#                cnlnagp            cnlnenp            cnlninp  \
# 0   0.0470721982419491                  0  0.320718288421631
# 1   0.0470721982419491                  0  0.320718288421631
# 2   0.0304461997002363                  0  0.317928194999695
# 3    0.533692181110382                  0  0.185248598456383
# 13    2.29296803474426  0.703820884227753   2.31013488769531
#
#                cnlntacp           cnlnedup           cnlnhthp  \
# 0   0.00690389983355999                  0                  0
# 1   0.00690389983355999                  0                  0
# 2   0.00292750005610287                  0                  0
# 3     0.567323684692383                  0                  0
# 13    0.713891804218292  0.320209890604019  0.201189801096916
#
#              cnlnothp
# 0   0.289336889982224
# 1   0.289336889982224
# 2   0.124712198972702
# 3   0.616943776607513
# 13   3.35064506530762

# %% [markdown]
# ### Grouping

# %% [markdown]
# #### Group by multiple columns

# %%
df_1.groupby(['countryc', 'year']).groups
# Out:
# {('Botswana', 1976): Int64Index([34], dtype='int64'),
#  ('Botswana', 1987): Int64Index([45], dtype='int64'),
#  ('Botswana', 1988): Int64Index([46], dtype='int64'),
#  ('Botswana', 1994): Int64Index([52], dtype='int64'),
#  ('Burkina Faso', 1973): Int64Index([5], dtype='int64'),
#  ('Burkina Faso', 1975): Int64Index([7], dtype='int64'),
#  ('Burkina Faso', 1976): Int64Index([8], dtype='int64'),
#  ('Burkina Faso', 1980): Int64Index([12], dtype='int64'),
#  ('Burkina Faso', 1983): Int64Index([15], dtype='int64'),
#  ('Burkina Faso', 1988): Int64Index([20], dtype='int64'),
#  ('Burkina Faso', 1990): Int64Index([22], dtype='int64'),
#  ('Burkina Faso', 1994): Int64Index([26], dtype='int64'),
#  ('Cameroon', 1971): Int64Index([55], dtype='int64'),
#  ('Cameroon', 1975): Int64Index([59], dtype='int64'),
#  ('Cameroon', 1979): Int64Index([63], dtype='int64'),
#  ('Cameroon', 1980): Int64Index([64], dtype='int64'),
#  ('Cameroon', 1982): Int64Index([66], dtype='int64'),
# ...

# %% [markdown]
# #### Calculate the aggregate of a group

# %%
df_1.groupby(['countryc', 'year']).agg(np.mean)
# Out:
#                         popn
# countryc     year
# Botswana     1976   782650.0
#              1987  1154280.0
#              1988  1195140.0
#              1994  1420270.0
# Burkina Faso 1973  5958700.0
# ...                      ...
# Mauritius    1970   829000.0
#              1978   930800.0
#              1989  1048560.0
#              1992  1081000.0
#              1993  1097000.0
#
# [75 rows x 1 columns]

# %% [markdown]
# ### Challenge
#
# Group the values in df_1 by their 'GDP per Capita in 1995'.

# %%
df_1.groupby(['gdnpp']).groups
# Out:
# {'1.79769313486232e+308': Int64Index([89, 205, 81, 90], dtype='int64'),
#  '1019.97100830078': Int64Index([190], dtype='int64'),
#  '1028.31005859375': Int64Index([34], dtype='int64'),
#  '1034.93701171875': Int64Index([74], dtype='int64'),
#  '1103.14099121094': Int64Index([73], dtype='int64'),
#  '1150.58203125': Int64Index([66], dtype='int64'),
#  '1268.93200683594': Int64Index([64], dtype='int64'),
#  '1342.97399902344': Int64Index([63], dtype='int64'),
#  '1579.29895019531': Int64Index([45], dtype='int64'),
#  '175.921997070312': Int64Index([26], dtype='int64'),
#  '178.331405639648': Int64Index([225], dtype='int64'),
#  '185.867706298828': Int64Index([226], dtype='int64'),
#  '187.163803100586': Int64Index([101], dtype='int64'),
#  '193.556701660156': Int64Index([92], dtype='int64'),
#  '2027.98706054688': Int64Index([271], dtype='int64'),
#  '2057.32299804688': Int64Index([46], dtype='int64'),
#  '2109.35009765625': Int64Index([282], dtype='int64'),
# ...

# %% [markdown]
# ### Binning data

# %%
df.shape
# Out:
# (301, 50)

# %%
pd.qcut(df['popn'], q=7).value_counts()
# Out:
# (16616600.0, 56404000.0]       43
# (2652272.857, 7886652.857]     43
# (463999.999, 953097.143]       43
# (10664697.143, 16616600.0]     42
# (7886652.857, 10664697.143]    42
# (1377285.714, 2652272.857]     42
# (953097.143, 1377285.714]      42
# Name: popn, dtype: int64

# %% [markdown]
# ### Challenge
#
# Bin the data in df_2 accordiing to the year.

# %%
df_2.shape
# Out:
# (56, 50)

# %%
pd.qcut(df_2['year'], q=7).value_counts()
# Out:
# (1970.999, 1974.0]      11
# (1988.286, 1990.0]       9
# (1984.429, 1988.286]     8
# (1978.0, 1981.0]         8
# (1990.0, 1995.0]         7
# (1981.0, 1984.429]       7
# (1974.0, 1978.0]         6
# Name: year, dtype: int64
